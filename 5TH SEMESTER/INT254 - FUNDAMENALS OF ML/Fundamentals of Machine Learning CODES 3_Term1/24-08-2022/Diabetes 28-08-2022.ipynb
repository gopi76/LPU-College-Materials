# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('diabetes_data.csv')

# %%
df
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0              6      148         72       35        0  33.6  0.627   50
# 1              1       85         66       29        0  26.6  0.351   31
# 2              8      183         64        0        0  23.3  0.672   32
# 3              1       89         66       23       94  28.1  0.167   21
# 4              0      137         40       35      168  43.1  2.288   33
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0              6      148         72       35        0  33.6  0.627   50
# 1              1       85         66       29        0  26.6  0.351   31
# 2              8      183         64        0        0  23.3  0.672   32
# 3              1       89         66       23       94  28.1  0.167   21
# 4              0      137         40       35      168  43.1  2.288   33
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 0           1
# 1           0
# ...

# %%
df.describe().T
# Out:
#              count        mean         std     min       25%       50%  \
# pregnancies  768.0    3.845052    3.369578   0.000   1.00000    3.0000
# glucose      768.0  120.894531   31.972618   0.000  99.00000  117.0000
# diastolic    768.0   69.105469   19.355807   0.000  62.00000   72.0000
# triceps      768.0   20.536458   15.952218   0.000   0.00000   23.0000
# insulin      768.0   79.799479  115.244002   0.000   0.00000   30.5000
# bmi          768.0   31.992578    7.884160   0.000  27.30000   32.0000
# dpf          768.0    0.471876    0.331329   0.078   0.24375    0.3725
# age          768.0   33.240885   11.760232  21.000  24.00000   29.0000
# diabetes     768.0    0.348958    0.476951   0.000   0.00000    0.0000
#
#                    75%     max
# pregnancies    6.00000   17.00
# glucose      140.25000  199.00
# diastolic     80.00000  122.00
# triceps       32.00000   99.00
# insulin      127.25000  846.00
# bmi           36.60000   67.10
# dpf            0.62625    2.42
# ...

# %%
df.nunique()
# Out:
# pregnancies     17
# glucose        136
# diastolic       47
# triceps         51
# insulin        186
# bmi            248
# dpf            517
# age             52
# diabetes         2
# dtype: int64

# %%
df.isna().sum()
# Out:
# pregnancies    0
# glucose        0
# diastolic      0
# triceps        0
# insulin        0
# bmi            0
# dpf            0
# age            0
# diabetes       0
# dtype: int64

# %%
df.duplicated().sum() #duplicate values checking
# Out:
# 0

# %%
x = df.drop(columns = ["diabetes"])       
y = df["diabetes"]

# %%
from sklearn.model_selection import train_test_split
#spliting data

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.02,random_state =123)
x_train.shape ,x_test.shape ,y_train.shape ,y_test.shape
# Out:
# ((752, 8), (16, 8), (752,), (16,))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
#fitting data in Logisticregression

logreg = LogisticRegression()
logreg.fit(x_train,y_train)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Ypred = logreg.predict(x_test)

# %%
print(Ypred)
# Out:
# [1 1 1 0 0 1 1 1 1 0 1 0 0 0 1 0]

# %%
from sklearn.metrics import classification_report , accuracy_score , f1_score,roc_curve,roc_auc_score,confusion_matrix
res = f1_score(y_test,Ypred)
print(res)
# Out:
# 0.8750000000000001

# %% [markdown]
# # practing 31-08-2022

# %%
df
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0              6      148         72       35        0  33.6  0.627   50
# 1              1       85         66       29        0  26.6  0.351   31
# 2              8      183         64        0        0  23.3  0.672   32
# 3              1       89         66       23       94  28.1  0.167   21
# 4              0      137         40       35      168  43.1  2.288   33
# ..           ...      ...        ...      ...      ...   ...    ...  ...
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
df.columns #.columns is used to print the column names in the given dataset
# Out:
# Index(['pregnancies', 'glucose', 'diastolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'diabetes'],
#       dtype='object')

# %%
df.columns=['a','b','c','d','e','f','g','h','i'] #we can modify our columns names for our conveinence without using the names

# %%
df  #printing the updated(columns..) dataset
# Out:
#       a    b   c   d    e     f      g   h  i
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
df.head()    #it will print the first 5 rows in the given dataset
# Out:
#    a    b   c   d    e     f      g   h  i
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
df.tail()    #it will print the last 5 rows in the given dataset
# Out:
#       a    b   c   d    e     f      g   h  i
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0

# %%
df.head(n = 10)  #it will print the first n rows in the given dataset
# Out:
#     a    b   c   d    e     f      g   h  i
# 0   6  148  72  35    0  33.6  0.627  50  1
# 1   1   85  66  29    0  26.6  0.351  31  0
# 2   8  183  64   0    0  23.3  0.672  32  1
# 3   1   89  66  23   94  28.1  0.167  21  0
# 4   0  137  40  35  168  43.1  2.288  33  1
# 5   5  116  74   0    0  25.6  0.201  30  0
# 6   3   78  50  32   88  31.0  0.248  26  1
# 7  10  115   0   0    0  35.3  0.134  29  0
# 8   2  197  70  45  543  30.5  0.158  53  1
# 9   8  125  96   0    0   0.0  0.232  54  1

# %%
df.tail(n = 10)  #it will print the last n rows in the given dataset
                #starts from o to n-1 rows ...
# Out:
#       a    b   c   d    e     f      g   h  i
# 758   1  106  76   0    0  37.5  0.197  26  0
# 759   6  190  92   0    0  35.5  0.278  66  1
# 760   2   88  58  26   16  28.4  0.766  22  0
# 761   9  170  74  31    0  44.0  0.403  43  1
# 762   9   89  62   0    0  22.5  0.142  33  0
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0

# %%
df.shape  #(768 , 9)    represents the 
       #   rows ,columns
# Out:
# (768, 9)

# %%
df.columns=['Name','b','Department','d','Roll Number','f','Registration Number','h','Pincode']

# %%
df
# Out:
#      Name    b  Department   d  Roll Number     f  Registration Number   h  \
# 0       6  148          72  35            0  33.6                0.627  50
# 1       1   85          66  29            0  26.6                0.351  31
# 2       8  183          64   0            0  23.3                0.672  32
# 3       1   89          66  23           94  28.1                0.167  21
# 4       0  137          40  35          168  43.1                2.288  33
# ..    ...  ...         ...  ..          ...   ...                  ...  ..
# 763    10  101          76  48          180  32.9                0.171  63
# 764     2  122          70  27            0  36.8                0.340  27
# 765     5  121          72  23          112  26.2                0.245  30
# 766     1  126          60   0            0  30.1                0.349  47
# 767     1   93          70  31            0  30.4                0.315  23
#
#      Pincode
# 0          1
# 1          0
# 2          1
# ...
